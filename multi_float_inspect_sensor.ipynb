# %%
import util as util

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
multi_float = util.load_multi_data(3,10, "float")
multi_int = util.load_multi_data(52,55, "int")

# %%
multi_float['sensor_id'].value_counts()
# Out:
# 6633.0    496858
# 6632.0    495961
# 6635.0    485599
# 6636.0    485593
# 6634.0    485506
# 6223.0    243004
# 6222.0    172032
# 6896.0    135453
# Name: sensor_id, dtype: int64

# %% [markdown]
# ### inspect 6632 (coffeemaker)

# %%
df = util.line_plot_multi(multi_float, 6632, "coffemaker", 490000, [0,2000])
min(df['timestamp']), max(df['timestamp'])
df[df['value'] > 100]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-9a5bb84abd21> in <module>
# ----> 1 df = util.line_plot_multi(multi_float, 6632, "coffemaker", 490000, [0,2000])
#       2 min(df['timestamp']), max(df['timestamp'])
#       3 df[df['value'] > 100]
#
# NameError: name 'multi_float' is not defined

# %%
util.hist_plot_multi(multi_float, 6632, "cooffeemaker", [0,100])
# Out:
#         value_id  sensor_id                   timestamp  value   time
# 66591    1913431       6632  2020-03-23 19:16:51.608084    0.0  69411
# 66595    1913437       6632  2020-03-23 19:16:52.878824    0.0  69412
# 66599    1913444       6632  2020-03-23 19:16:54.169861    0.0  69414
# 66607    1913455       6632  2020-03-23 19:16:55.777377    0.0  69415
# 66612    1913462       6632  2020-03-23 19:16:57.096640    0.0  69417
# ...          ...        ...                         ...    ...    ...
# 499972   6069960       6632  2020-04-09 15:12:45.308359    0.0  54765
# 499982   6069970       6632  2020-04-09 15:12:46.979827    0.0  54766
# 499988   6069976       6632  2020-04-09 15:12:48.364100    0.0  54768
# 499994   6069982       6632  2020-04-09 15:12:49.646718    0.0  54769
# 500000   6069988       6632  2020-04-09 15:12:50.948673    0.0  54770
#
# [568794 rows x 5 columns]

# %% [markdown]
# ### inspect 6633 sandwichmaker

# %%
df = util.line_plot_multi(multi_float, 6633, "sandwichmaker", 550000, [0,2200])
# Out:
# 570480

# %%
df = util.hist_plot_multi(multi_float, 6633, "sandwichmaker", [0,300])

# %% [markdown]
# ## inspect 6635 kettle

# %%
df = util.line_plot_multi(multi_float, 6635, "kettle", 550000, [0,600])

# %%
df = util.hist_plot_multi(multi_float, 6635, "kettle", [0,100000])

# %% [markdown]
# ## inspect 6896 microwave

# %%
df = util.line_plot_multi(multi_float, 6896, "microwave", 55000, [0,1500])

# %%
df = util.hist_plot_multi(multi_float, 6896, "microwave", [0,400])

# %% [markdown]
# # Multi_sensor_Int

# %% [markdown]
# ## inspect 5895 bathroom

# %%
multi_int
# Out:
#         value_id  sensor_id                   timestamp  value   time
# 0       61071473       5891  2020-03-24 16:50:55.682281      0  60655
# 1       61071474       5895  2020-03-24 16:50:55.754753      0  60655
# 2       61071475       5894  2020-03-24 16:50:55.766631      0  60655
# 3       61071476       6686  2020-03-24 16:50:55.970343      0  60655
# 4       61071477       5889  2020-03-24 16:50:56.015072    261  60656
# ...          ...        ...                         ...    ...    ...
# 499996  63387902       6687  2020-03-26 10:54:37.518536      6  39277
# 499997  63387903       5895  2020-03-26 10:54:37.525842      1  39277
# 499998  63387905       6127  2020-03-26 10:54:37.671368   1024  39277
# 499999  63387906       6253  2020-03-26 10:54:37.805541      0  39277
# 500000  63387909       5893  2020-03-26 10:54:38.075714      0  39278
#
# [1500003 rows x 5 columns]

# %%
df = util.line_plot_multi(multi_int, 5895, "bathroom motion", 120000, [0,10])

# %%
df = util.hist_plot_multi(multi_int, 5895, "bathroom motion", [0,400000])

# %% [markdown]
# ## inspect 5896 bed pressure

# %%
df = util.line_plot_multi(multi_int, 5896, "bed pressure", 91000, [600,680])

# %%
df = util.hist_plot_multi(multi_int, 5896, "bed pressure", [0,50000])

# %% [markdown]
# ## inspect 5889 couch pressure

# %%
df = util.line_plot_multi(multi_int, 5889, "couch pressure", 340000, [200,440])

# %%
df = util.hist_plot_multi(multi_int, 5889, "couch pressure", [0,100000])

# %% [markdown]
# ## inspect 5893 kitchen motion

# %%
df = util.line_plot_multi(multi_int, 5893, "kitchen motion", 340000, [200,440])

# %%
df = util.hist_plot_multi(multi_int, 5893, "kitchen motion", [0,100000])
